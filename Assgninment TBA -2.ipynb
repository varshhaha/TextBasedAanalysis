# %% [markdown]
# # Opening the data file

# %%
import pandas as pd
data = ("C:\\Users\\varsh\\Downloads\\googleplaystore_user_reviews.csv")

# %%
df= pd.read_csv(data)
df.head(20)
# Out:
#                       App                                  Translated_Review  \
# 0   10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1   10 Best Foods for You    This help eating healthy exercise regular basis
# 2   10 Best Foods for You                                                NaN
# 3   10 Best Foods for You         Works great especially going grocery store
# 4   10 Best Foods for You                                       Best idea us
# 5   10 Best Foods for You                                           Best way
# 6   10 Best Foods for You                                            Amazing
# 7   10 Best Foods for You                                                NaN
# 8   10 Best Foods for You                               Looking forward app,
# 9   10 Best Foods for You              It helpful site ! It help foods get !
# 10  10 Best Foods for You                                          good you.
# ...

# %%
## Open the file and randomly select 20%
#df = df.sample(frac=0.2)

# %%
#columns
df.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
#types of data
df.dtypes
# Out:
# App                        object
# Translated_Review          object
# Sentiment                  object
# Sentiment_Polarity        float64
# Sentiment_Subjectivity    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
df.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %%
## LENGTH OF SPEECHES

# %%
df['length'] = df['Translated_Review'].str.len()
df.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity        length
# count        37432.000000            37432.000000  37427.000000
# mean             0.182146                0.492704    113.211906
# std              0.351301                0.259949    105.103471
# min             -1.000000                0.000000      2.000000
# 25%              0.000000                0.357143     33.000000
# 50%              0.150000                0.514286     86.000000
# 75%              0.400000                0.650000    165.000000
# max              1.000000                1.000000   2713.000000

# %%
##stats about text fields
df.describe(include='O')
# Out:
#                         App Translated_Review Sentiment
# count                 64295             37427     37432
# unique                 1074             27994         3
# top     Angry Birds Classic              Good  Positive
# freq                    320               247     23998

# %%
##Checking for missing data
df.isna().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# length                    26868
# dtype: int64

# %%
df['Translated_Review'].fillna('unknown', inplace=True)
df
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                unknown       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %%
#fill the missing data
df['Sentiment'].fillna('unknown', inplace=True)
df
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                unknown   unknown
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %%
#fill the missing data
df['Sentiment_Polarity'].fillna('unknown', inplace=True)
df
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                unknown   unknown
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %%
df.isna().sum()
# Out:
# App                           0
# Translated_Review             0
# Sentiment                     0
# Sentiment_Polarity            0
# Sentiment_Subjectivity    26863
# length                    26868
# dtype: int64

# %%
#return in upper case
df['Translated_Review'] = df['Translated_Review'].str.upper()
df
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I LIKE EAT DELICIOUS FOOD. THAT'S I'M COOKING ...  Positive
# 1        THIS HELP EATING HEALTHY EXERCISE REGULAR BASIS  Positive
# 2                                                UNKNOWN   unknown
# 3             WORKS GREAT ESPECIALLY GOING GROCERY STORE  Positive
# 4                                           BEST IDEA US  Positive
# ...                                                  ...       ...
# ...

# %%
df[df['App'].str.contains('Best')]
df
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I LIKE EAT DELICIOUS FOOD. THAT'S I'M COOKING ...  Positive
# 1        THIS HELP EATING HEALTHY EXERCISE REGULAR BASIS  Positive
# 2                                                UNKNOWN   unknown
# 3             WORKS GREAT ESPECIALLY GOING GROCERY STORE  Positive
# 4                                           BEST IDEA US  Positive
# ...                                                  ...       ...
# ...

# %% [markdown]
# # plots

# %%
#chart
df['length'].plot()
df
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I LIKE EAT DELICIOUS FOOD. THAT'S I'M COOKING ...  Positive
# 1        THIS HELP EATING HEALTHY EXERCISE REGULAR BASIS  Positive
# 2                                                UNKNOWN   unknown
# 3             WORKS GREAT ESPECIALLY GOING GROCERY STORE  Positive
# 4                                           BEST IDEA US  Positive
# ...                                                  ...       ...
# ...

# %%
#chart
df['length'].plot(kind='box', vert=False)
df
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I LIKE EAT DELICIOUS FOOD. THAT'S I'M COOKING ...  Positive
# 1        THIS HELP EATING HEALTHY EXERCISE REGULAR BASIS  Positive
# 2                                                UNKNOWN   unknown
# 3             WORKS GREAT ESPECIALLY GOING GROCERY STORE  Positive
# 4                                           BEST IDEA US  Positive
# ...                                                  ...       ...
# ...

# %%
#Histogram
df['length'].plot(kind='hist', bins=30)
df
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I LIKE EAT DELICIOUS FOOD. THAT'S I'M COOKING ...  Positive
# 1        THIS HELP EATING HEALTHY EXERCISE REGULAR BASIS  Positive
# 2                                                UNKNOWN   unknown
# 3             WORKS GREAT ESPECIALLY GOING GROCERY STORE  Positive
# 4                                           BEST IDEA US  Positive
# ...                                                  ...       ...
# ...

# %%
#bhar
import seaborn as sns
where = df['Sentiment'].isin(['Positive', 'Neutral', 'Negative', 'NaN'])
g = sns.catplot(data=df[where], x="Sentiment", y="length", kind='box')
g.fig.set_size_inches(10, 8) ###

# %% [markdown]
# # Regex

# %%
import regex as re
def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)

# %%
##REMOVE STOP WORDS
import regex as re
import nltk
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {'mightn', 'each', 'y', 'only', 'my', 'will', 'be', 'from', 'hadn', 'mustn', 'has', 'no', 'didn', "you've", 'you', 'before', 'wasn', 'them', 'her', 'once', 'o', 'the', 'being', "it's", 'by', "mustn't", 'me', "doesn't", 'its', 's', 'll', 'how', 'during', "didn't", 'yours', "wouldn't", 'about', 'had', 'shan', 'doing', "couldn't", "you're", 'over', 'again', 'nor', 'which', "you'd", 'between', 'above', "aren't", 'don', 'as', 'if', 'out', 'through', 'who', 'because', 'won', 'ours', 'an', 'most', "won't", 'with', 'there', 'couldn', 'have', 'while', "hasn't", 'all', 'own', 'this', 'aren', 'against', 'were', 'their', 'not', 'd', 'they', 'these', 'ain', 'isn', 'and', 'until', 'on', 'yourself', 'themselves', 'more', "haven't", 'are', 're', 'our', 'myself', 've', 'or', 'theirs', 'am', 'same', 'further', 'few', 'hasn', 'here', "hadn't", 'm', 'himself', "you'll", 'needn', "should've", 'is', 'too', 'off', 'in', 'yourselves', 'at', 'up', "shan't", 't', 'weren', 'hers', 'his', 'very', 'doesn', 'itse
# ...

# %%
#stopwords
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]

# %% [markdown]
# # pipeline

# %%
pipeline = [str.lower, tokenize, remove_stop]

# %%
def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
        return tokens

# %%
##running pipeline
df['tokens'] = df['Translated_Review'].apply(prepare,pipeline=pipeline)
df['num_tokens'] = df['tokens'].map(len)
df.tail()
# Out:
#                                App Translated_Review Sentiment  \
# 64290  Houzz Interior Design Ideas           UNKNOWN   unknown
# 64291  Houzz Interior Design Ideas           UNKNOWN   unknown
# 64292  Houzz Interior Design Ideas           UNKNOWN   unknown
# 64293  Houzz Interior Design Ideas           UNKNOWN   unknown
# 64294  Houzz Interior Design Ideas           UNKNOWN   unknown
#
#       Sentiment_Polarity  Sentiment_Subjectivity  length   tokens  num_tokens
# 64290            unknown                     NaN     NaN  unknown           7
# 64291            unknown                     NaN     NaN  unknown           7
# 64292            unknown                     NaN     NaN  unknown           7
# 64293            unknown                     NaN     NaN  unknown           7
# 64294            unknown                     NaN     NaN  unknown           7

# %%
from collections import Counter
counter = Counter()

# %%
df['tokens'].map(counter.update)
print(counter.most_common(5))
freq_df = pd.DataFrame.from_dict(counter,orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'
# Out:
# [(' ', 649381), ('e', 434698), ('n', 297444), ('i', 266826), ('t', 265964)]

# %%
## Sort and display

freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
freq_df.describe()
# Out:
#                 freq
# count     235.000000
# mean    18830.897872
# std     69851.707553
# min         1.000000
# 25%         1.000000
# 50%         3.000000
# 75%        62.000000
# max    649381.000000

# %%
# bar plot
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8))
ax.invert_yaxis()
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %% [markdown]
# # Wordcloud

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt
text = df.query("Sentiment_Polarity == 0.5 and Sentiment == 'Positive'")['Translated_Review'].values[0]
plt.figure(figsize=(14, 7)) ###

# %%
wc = WordCloud(max_words=100, stopwords=stopwords)

# %%
wc.generate(text)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
wc = WordCloud(background_color='white', width = 300, height=300,max_words=100, margin=2)
wc.fit_words(freq_df['freq'].to_dict() )

# %%
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()
